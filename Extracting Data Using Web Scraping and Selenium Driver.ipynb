# %%
import re
import csv
from getpass import getpass
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from msedge.selenium_tools import Edge, EdgeOptions

def get_tweet_data(card):
    """Extract data from tweet card"""
    username = card.find_element("xpath",'.//span').text
    try:
        handle = card.find_element("xpath",'.//span[contains(text(), "@")]').text
    except NoSuchElementException:
        return
    
    try:
        postdate = card.find_element("xpath",'.//time').get_attribute('datetime')
    except NoSuchElementException:
        return
    
    comment = card.find_element("xpath",'.//div[2]/div[2]/div[1]').text
    responding = card.find_element("xpath",'.//div[2]/div[2]/div[2]').text
    text = comment + responding
    reply_cnt = card.find_element("xpath",'.//div[@data-testid="reply"]').text
    retweet_cnt = card.find_element("xpath",'.//div[@data-testid="retweet"]').text
    like_cnt = card.find_element("xpath",'.//div[@data-testid="like"]').text
    
    # get a string of all emojis contained in the tweet
    """Emojis are stored as images... so I convert the filename, which is stored as unicode, into 
    the emoji character."""
    emoji_tags = card.find_elements("xpath",'.//img[contains(@src, "emoji")]')
    emoji_list = []
    for tag in emoji_tags:
        filename = tag.get_attribute('src')
        try:
            emoji = chr(int(re.search(r'svg\/([a-z0-9]+)\.svg', filename).group(1), base=16))
        except AttributeError:
            continue
        if emoji:
            emoji_list.append(emoji)
    emojis = ' '.join(emoji_list)
    
    tweet = (username, handle, postdate, text, emojis, reply_cnt, retweet_cnt, like_cnt)
    return tweet

# %%
# application variables
user = input('username: ')
my_password = getpass('Password: ')
search_term = input('search term: ')

# create instance of web driver
options = EdgeOptions()
options.use_chromium = True
driver = Edge(options=options)

# navigate to login screen
driver.get('https://www.twitter.com/login')
driver.maximize_window()
sleep(5)
username = driver.find_element("xpath",'//input[@name="text"]')
username.send_keys(user)
username.send_keys(Keys.RETURN)
sleep(3)

password = driver.find_element('xpath','//input[@name="password"]')
password.send_keys(my_password)
password.send_keys(Keys.RETURN)
sleep(3)

# find search input and search for term
search_input = driver.find_element('xpath','//input[@aria-label="Search query"]')
search_input.send_keys(search_term)
search_input.send_keys(Keys.RETURN)
sleep(1)

# navigate to historical 'latest' tab
driver.find_element_by_link_text('Latest').click()
# Out:
# username: Dathu55483800
# Password: ········
# search term: #VMwareExplore
# C:\Users\kldat\AppData\Local\Temp\ipykernel_17020\1838143494.py:9: DeprecationWarning: Selenium Tools for Microsoft Edge is deprecated. Please upgrade to Selenium 4 which has built-in support for Microsoft Edge (Chromium): https://docs.microsoft.com/en-us/microsoft-edge/webdriver-chromium/#upgrading-from-selenium-3
#   driver = Edge(options=options)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17020\1838143494.py in <module>
#      30
#      31 # navigate to historical 'latest' tab
# ---> 32 driver.find_element_by_link_text('Latest').click()
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_link_text'

# %%
# get all tweets on the page
data = []
twitter_tweet_ = []
tweet_ids = set()
last_position = driver.execute_script("return window.pageYOffset;")
scrolling = True

while scrolling:
    page_cards = driver.find_elements('xpath', '//article[@data-testid="tweet"]')
    for card in page_cards[-15:]:
        tweet = get_tweet_data(card)
        if tweet:
            tweet_id = ''.join(tweet)
            if tweet_id not in tweet_ids:
                tweet_ids.add(tweet_id)
                data.append(tweet)
                twitter_tweet_.append(tweet[3])
            
    scroll_attempt = 0
    while True:
        # check scroll position
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(2)
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position:
            scroll_attempt += 1
            
            # end of scroll region
            if scroll_attempt >= 3:
                scrolling = False
                break
            else:
                sleep(2) # attempt another scroll
        else:
            last_position = curr_position
            break

# close the web driver
driver.close()

# %%
len(data)
# Out:
# 44

# %% [markdown]
# Saving the twitter data

# %%
with open('demo.csv', 'w', newline='', encoding='utf-8') as f:
    header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(data)

# %%
import pandas as pd
header = ['UserName', 'Handle', 'Timestamp', 'Text', 'Emojis', 'Comments', 'Likes', 'Retweets']
df = pd.DataFrame(data,columns= header)
df.head()
# Out:
#           UserName           Handle                 Timestamp  \
# 0  Ashutosh mourya      @Anurag_091  2023-04-11T06:20:19.000Z
# 1               m.      @imshivans7  2023-04-11T06:20:13.000Z
# 2     Shivam Singh      @mrshivam_9  2023-04-11T06:20:02.000Z
# 3     Kapil mishra  @imkapil_mishra  2023-04-11T06:19:55.000Z
# 4            vijay     @vijay__raj6  2023-04-11T06:19:55.000Z
#
#                                                 Text Emojis Comments Likes  \
# 0  Ashutosh mourya\n@Anurag_091\n·\n2mThat's some...
# 1  m.\n@imshivans7\n·\n2mஇது ஒரு சிறப்பு மற்றும் ...
# 2  Shivam Singh\n@mrshivam_9\n·\n2mThat's somethi...
# 3  Kapil mishra\n@imkapil_mishra\n·\n2mThe one wh...                     1
# 4  vijay\n@vijay__raj6\n·\n2mતે આ માટે કંઈક ખાસ અ...
#
#   Retweets
# 0
# 1
# 2
# 3
# 4

# %%
twitter_tweet = pd.array(twitter_tweet_)
df['Text'] = twitter_tweet

# %%
df.head() # gives the updated dataset
# Out:
#           UserName           Handle                 Timestamp  \
# 0  Ashutosh mourya      @Anurag_091  2023-04-11T06:20:19.000Z
# 1               m.      @imshivans7  2023-04-11T06:20:13.000Z
# 2     Shivam Singh      @mrshivam_9  2023-04-11T06:20:02.000Z
# 3     Kapil mishra  @imkapil_mishra  2023-04-11T06:19:55.000Z
# 4            vijay     @vijay__raj6  2023-04-11T06:19:55.000Z
#
#                                                 Text Emojis Comments Likes  \
# 0  Ashutosh mourya
# @Anurag_091
# ·
# 2mThat's somethi...
# 1  m.
# @imshivans7
# ·
# 2mஇது ஒரு சிறப்பு மற்றும் மகி...
# 2  Shivam Singh
# @mrshivam_9
# ·
# 2mThat's something ...
# 3  Kapil mishra
# @imkapil_mishra
# ·
# 2mThe one who h...                     1
# 4  vijay
# @vijay__raj6
# ·
# 2mતે આ માટે કંઈક ખાસ અને ...
#
#   Retweets
# 0
# 1
# 2
# 3
# 4

# %%
df.tail()
# Out:
#          UserName            Handle                 Timestamp  \
# 39    Shree Radhe        @imradhe95  2023-04-11T06:06:17.000Z
# 40    Parul Patel         @Parul2fb  2023-04-11T06:06:16.000Z
# 41    Jyoti Singh        @Jyoti_S12  2023-04-11T06:06:12.000Z
# 42          punam    @Punampanday87  2023-04-11T06:06:05.000Z
# 43  sweety sharma  @sweetysharma108  2023-04-11T06:06:03.000Z
#
#                                                  Text Emojis Comments Likes  \
# 39  Shree Radhe
# @imradhe95
# ·
# 16mಇದು ಮುಂಬೈನಲ್ಲಿ ನಡೆ...
# 40  Parul Patel
# @Parul2fb
# ·
# 16mIf you want to see ...
# 41  Jyoti Singh
# @Jyoti_S12
# ·
# 16mYah interesting ev...
# 42  punam
# @Punampanday87
# ·
# 16myou won't want to mi...
# 43  sweety sharma
# @sweetysharma108
# ·
# 16mAt #VMware...
#
#    Retweets
# 39
# 40
# 41
# 42
# 43

# %%
df.to_csv('mydata.csv', index=False)

# %%
data
# Out:
# [('Ashutosh mourya',
#   '@Anurag_091',
#   '2023-04-11T06:20:19.000Z',
#   "Ashutosh mourya\n@Anurag_091\n·\n2mThat's something special and happy for this one #VMwareExplore",
#   '',
#   '',
#   '',
#   ''),
#  ('m.',
#   '@imshivans7',
#   '2023-04-11T06:20:13.000Z',
#   'm.\n@imshivans7\n·\n2mஇது ஒரு சிறப்பு மற்றும் மகிழ்ச்சியான விஷயம் #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Shivam Singh',
#   '@mrshivam_9',
#   '2023-04-11T06:20:02.000Z',
#   "Shivam Singh\n@mrshivam_9\n·\n2mThat's something special and happy for this one #VMwareExplore",
#   '',
#   '',
#   '',
#   ''),
#  ('Kapil mishra',
#   '@imkapil_mishra',
#   '2023-04-11T06:19:55.000Z',
#   'Kapil mishra\n@imkapil_mishra\n·\n2mThe one who has medicine for every pain.... That unique relationship is parents...\n#भ्रष्टाचार_खिलाफ_पायलट\n#VMwareExplore\n#ClimateSmartUP\n#VMwareIndia #TejRan',
#   '',
#   '',
#   '1',
#   ''),
#  ('vijay',
#   '@vijay__raj6',
#   '2023-04-11T06:19:55.000Z',
#   'vijay\n@vijay__raj6\n·\n2mતે આ માટે કંઈક ખાસ અને ખુશ છે #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Raja',
#   '@iam_raja100',
#   '2023-04-11T06:19:44.000Z',
#   'Raja\n@iam_raja100\n·\n2mಇದು ವಿಶೇಷ ಮತ್ತು ಸಂತೋಷದ ಸಂಗತಿಯಾಗಿದೆ #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Arun tiwari',
#   '@Aruntiwari509',
#   '2023-04-11T06:19:33.000Z',
#   "Arun tiwari\n@Aruntiwari509\n·\n3mThat's something special and happy for this one #VMwareExplore",
#   '',
#   '',
#   '',
#   ''),
#  ('Pavan thakur',
#   '@Pavan_thakur0',
#   '2023-04-11T06:19:24.000Z',
#   'Pavan thakur\n@Pavan_thakur0\n·\n3mਇਹ ਇਸ ਲਈ ਕੁਝ ਖਾਸ ਅਤੇ ਖੁਸ਼ੀ ਵਾਲੀ ਗੱਲ ਹੈ #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('kanhaiya',
#   '@Rishi_xtp',
#   '2023-04-11T06:19:08.000Z',
#   'kanhaiya\n@Rishi_xtp\n·\n3mइसके लिए यह कुछ खास और खुशी की बात है #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Anubhav',
#   '@Anubhav1t',
#   '2023-04-11T06:18:56.000Z',
#   "Anubhav\n@Anubhav1t\n·\n3mThat's something special and happy for this one #VMwareExplore",
#   '',
#   '',
#   '',
#   ''),
#  ('imshivaaye',
#   '@anzalisingh7',
#   '2023-04-11T06:18:44.000Z',
#   "imshivaaye\n@anzalisingh7\n·\n4mThat's something special and happy for this one #VMwareExplore",
#   '',
#   '',
#   '',
#   ''),
#  ('Shree Radhe',
#   '@imradhe95',
#   '2023-04-11T06:17:57.000Z',
#   'Shree Radhe\n@imradhe95\n·\n4mஏய் ட்வீப்ஸ் இந்த ஆண்டின் மிகப்பெரிய மல்டி கிளவுட் நிகழ்வின் ஒரு பகுதியாக இருக்க தவறாதீர்கள் VMware Explore இது மும்பையில் நடக்கிறது.. #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Isshu',
#   '@iamishu09',
#   '2023-04-11T06:17:41.000Z',
#   'Isshu\n@iamishu09\n·\n5mહે ટ્વીપ્સ આ વર્ષની સૌથી મોટી મલ્ટી-ક્લાઉડ ઇવેન્ટનો ભાગ બનવાનું ચૂકશો નહીં VMware એક્સપ્લોર જે મુંબઈમાં થઈ રહ્યું છે. #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Raghav',
#   '@imraghaav09',
#   '2023-04-11T06:17:30.000Z',
#   'Raghav\n@imraghaav09\n·\n5mਹੇ ਟਵੀਪਸ ਸਾਲ ਦੇ ਇਸ ਸਭ ਤੋਂ ਵੱਡੇ ਮਲਟੀ-ਕਲਾਊਡ ਈਵੈਂਟ ਦਾ ਹਿੱਸਾ ਬਣਨ ਲਈ ਨਾ ਭੁੱਲੋ VMware ਐਕਸਪਲੋਰ ਜੋ ਕਿ ਮੁੰਬਈ ਵਿੱਚ ਹੋ ਰਿਹਾ ਹੈ. #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Ashutosh mourya',
#   '@Anurag_091',
#   '2023-04-11T06:17:16.000Z',
#   'Ashutosh mourya\n@Anurag_091\n·\n5mਹੇ ਟਵੀਪਸ ਸਾਲ ਦੇ ਇਸ ਸਭ ਤੋਂ ਵੱਡੇ ਮਲਟੀ-ਕਲਾਊਡ ਈਵੈਂਟ ਦਾ ਹਿੱਸਾ ਬਣਨ ਲਈ ਨਾ ਭੁੱਲੋ VMware ਐਕਸਪਲੋਰ ਜੋ ਕਿ ਮੁੰਬਈ ਵਿੱਚ ਹੋ ਰਿਹਾ ਹੈ. #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('mr_shivay',
#   '@iam_shivay7',
#   '2023-04-11T06:16:52.000Z',
#   'mr_shivay\n@iam_shivay7\n·\n5mਹੇ ਟਵੀਪਸ ਸਾਲ ਦੇ ਇਸ ਸਭ ਤੋਂ ਵੱਡੇ ਮਲਟੀ-ਕਲਾਊਡ ਈਵੈਂਟ ਦਾ ਹਿੱਸਾ ਬਣਨ ਲਈ ਨਾ ਭੁੱਲੋ VMware ਐਕਸਪਲੋਰ ਜੋ ਕਿ ਮੁੰਬਈ ਵਿੱਚ ਹੋ ਰਿਹਾ ਹੈ. #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Mr Rangbaz',
#   '@mr_rangbaz18',
#   '2023-04-11T06:16:30.000Z',
#   'Mr Rangbaz\n@mr_rangbaz18\n·\n6mनमस्ते ट्वीट्स वर्ष के इस सबसे बड़े मल्टी-क्लाउड इवेंट का हिस्सा बनने से न चूकें वीएमवेयर एक्सप्लोर जो मुंबई में हो रहा है. #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('𝐌𝐚𝐧_𝐄𝐞𝐬𝐡™',
#   '@Mr_Python17',
#   '2023-04-11T06:16:18.000Z',
#   '𝐌𝐚𝐧_𝐄𝐞𝐬𝐡™\n@Mr_Python17\n·\n6mThe biggest multi-cloud event of the year #VMwareExplore is happening right now in Mumbai! An absolute paradise for all the tech lovers!',
#   '',
#   '',
#   '',
#   ''),
#  ('Satish',
#   '@irock_man080',
#   '2023-04-11T06:16:11.000Z',
#   "Satish\n@irock_man080\n·\n6mHey tweeps don't miss to be a part of this biggest multi-cloud event of the year VMware Explore which is happening  ow in Mumbai. #VMwareExplore",
#   '',
#   '',
#   '',
#   ''),
#  ('Arman Malik',
#   '@Armanmalik9582',
#   '2023-04-11T06:13:02.000Z',
#   'Arman Malik\n@Armanmalik9582\n·\n9mThe Biggest #Multicloud event #VMwareExplore is now happening in Mumbai !!',
#   '',
#   '',
#   '',
#   ''),
#  ('sonam gupta',
#   '@sonamgupta124',
#   '2023-04-11T06:09:02.000Z',
#   "sonam gupta\n@sonamgupta124\n·\n13m#VMwareExplore, we're seeing firsthand how multi-cloud technology is revolutionizing the industry.",
#   '',
#   '',
#   '',
#   ''),
#  ('Khushi verma',
#   '@khushiverma100',
#   '2023-04-11T06:08:43.000Z',
#   "Khushi verma\n@khushiverma100\n·\n14mAt #VMwareExplore, we're seeing firsthand how",
#   '',
#   '',
#   '',
#   ''),
#  ('Sapna',
#   '@Sapna_T01',
#   '2023-04-11T06:08:32.000Z',
#   'Sapna\n@Sapna_T01\n·\n14mise dekhne ke bad mujhe bahut hi Khushi Hui main yahan se bahut kuchh sikhane wala hun\n#VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Karan Kundra',
#   '@Kundrakaran23',
#   '2023-04-11T06:08:31.000Z',
#   'Karan Kundra\n@Kundrakaran23\n·\n14mEveryone should take a look at this #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Saurabh Mlm Srivastava',
#   '@MlmSaurabh',
#   '2023-04-11T06:08:30.000Z',
#   'Saurabh Mlm Srivastava\n@MlmSaurabh\n·\n14mత్వరపడండి అబ్బాయిలు ఈ ఈవెంట్\u200cలో దేనినీ మిస్ చేసుకోకండి #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Radha',
#   '@Radhagupta87',
#   '2023-04-11T06:08:24.000Z',
#   'Radha\n@Radhagupta87\n·\n14m#VMwareExplore,\nthe latest trends in multi-cloud technology!',
#   '',
#   '',
#   '',
#   ''),
#  ('Deepa',
#   '@Deeps_d1',
#   '2023-04-11T06:08:05.000Z',
#   'Deepa\n@Deeps_d1\n·\n14mSabhi logon Ko iske sath judna chahie aur ise dekhna chahie Jahan per hamen bahut kuchh sikhane ko milane wala hai\n#VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Avinash',
#   '@Craziavi707160',
#   '2023-04-11T06:07:59.000Z',
#   'Avinash\n@Craziavi707160\n·\n14mVMware ఎక్స్\u200cప్లోర్ ఈవెంట్ పూర్తి స్వింగ్\u200cలో ఉంది! అన్ని స్ఫూర్తిని పొందడం మరియు ఈవెంట్ ఆఫర్\u200cలను నేర్చుకోవడం ఆనందంగా ఉంది! #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Namrata Singh',
#   '@NamrataSingh520',
#   '2023-04-11T06:07:58.000Z',
#   "Namrata Singh\n@NamrataSingh520\n·\n14mWe can't wait to learn more about the latest trends in multi-cloud technology\n#VMwareExplore,",
#   '',
#   '',
#   '',
#   ''),
#  ('Virat Kohli',
#   '@imVkohali18',
#   '2023-04-11T06:07:45.000Z',
#   "Virat Kohli\n@imVkohali18\n·\n15m#VMwareExplore 'ਤੇ ਉਤਸ਼ਾਹ ਦੇਖਣਯੋਗ ਹੈ, ਮੁੰਬਈ ਵਿੱਚ ਹੋਣ ਵਾਲੇ ਅੰਤਮ ਮਲਟੀ-ਕਲਾਊਡ ਇਵੈਂਟ!  ਇਹ ਇਵੈਂਟ ਉੱਥੇ ਮੌਜੂਦ ਸਾਰੇ ਤਕਨੀਕੀ ਉਤਸ਼ਾਹੀਆਂ ਲਈ ਲਾਜ਼ਮੀ ਹੈ!",
#   '',
#   '',
#   '',
#   ''),
#  ('Kajal Tiwari',
#   '@Tiwa_Kajal',
#   '2023-04-11T06:07:34.000Z',
#   'Kajal Tiwari\n@Tiwa_Kajal\n·\n15mbahut hi behtarin program organised Kiya Gaya hai Jahan per hamen acchi chijen dekhne ko milane wali hai yaaron\n#VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Aarohiyadav',
#   '@Aarohiyadav444',
#   '2023-04-11T06:07:24.000Z',
#   "Aarohiyadav\n@Aarohiyadav444\n·\n15m#VMwareExplore event takes center stage!  We can't wait to learn more about the latest trends in",
#   '',
#   '',
#   '',
#   ''),
#  ('Mukesh Parmar™',
#   '@mukeshparmar146',
#   '2023-04-11T06:07:21.000Z',
#   'Mukesh Parmar™\n@mukeshparmar146\n·\n15mਸਭ ਤੋਂ ਵੱਡੇ  ਮਲਟੀਕਲਾਉਡ ਇਵੈਂਟ ਦਾ ਦਰਵਾਜ਼ਾ - #VMwareExplore ਹੁਣ ਖੁੱਲ੍ਹਾ ਹੈ!  ਇਸ ਵਿਸ਼ਾਲਤਾ ਦੀ ਘਟਨਾ ਨੂੰ ਦੇਖ ਕੇ ਕਿੰਨੀ ਖ਼ੁਸ਼ੀ ਹੁੰਦੀ ਹੈ!',
#   '',
#   '',
#   '',
#   ''),
#  ('Preeti Singh',
#   '@PreetiKumari520',
#   '2023-04-11T06:07:05.000Z',
#   'Preeti Singh\n@PreetiKumari520\n·\n15m#VMwareExplore event takes center stage!',
#   '',
#   '',
#   '',
#   ''),
#  ('Suman',
#   '@Sig_uttam',
#   '2023-04-11T06:06:59.000Z',
#   'Suman\n@Sig_uttam\n·\n15msabhi ko is event ko dekhna chahie ya Hamare knowledge ko enhance karne mein help Karega\n#VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Punam Singh',
#   '@PoojaSingh520',
#   '2023-04-11T06:06:48.000Z',
#   'Punam Singh\n@PoojaSingh520\n·\n16mMumbai is buzzing with energy as the #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('govind kumar',
#   '@praveshdoor',
#   '2023-04-11T06:06:29.000Z',
#   'govind kumar\n@praveshdoor\n·\n16mThe Jio World Center in Mumbai is humming with energy as the #VMwareExplore occasion becomes the dominant focal point! We can hardly hold on to get familiar with the most recent patterns in multi-cloud innovation!',
#   '',
#   '',
#   '',
#   ''),
#  ('Rani pandey',
#   '@Ranipanday124',
#   '2023-04-11T06:06:23.000Z',
#   'Rani pandey\n@Ranipanday124\n·\n16mThe Jio World Center in Mumbai is buzzing with energy as the #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Abhi',
#   '@Abhi86_',
#   '2023-04-11T06:06:21.000Z',
#   "Abhi\n@Abhi86_\n·\n16mOne more great event is here let's support this #VMwareExplore",
#   '',
#   '',
#   '',
#   ''),
#  ('Shree Radhe',
#   '@imradhe95',
#   '2023-04-11T06:06:17.000Z',
#   'Shree Radhe\n@imradhe95\n·\n16mಇದು ಮುಂಬೈನಲ್ಲಿ ನಡೆಯುತ್ತಿರುವ ಮಹೋನ್ನತ ಘಟನೆಯಾಗಿದೆ ಮತ್ತು ಇದು ಟೆಕ್ ಪ್ರಿಯರಿಗಾಗಿ #VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Parul Patel',
#   '@Parul2fb',
#   '2023-04-11T06:06:16.000Z',
#   'Parul Patel\n@Parul2fb\n·\n16mIf you want to see something good then you should see this event \n#VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('Jyoti Singh',
#   '@Jyoti_S12',
#   '2023-04-11T06:06:12.000Z',
#   'Jyoti Singh\n@Jyoti_S12\n·\n16mYah interesting event dekhne ke liye main excited hun yahan per behtarin Anubhav dekhne ko milega\n#VMwareExplore',
#   '',
#   '',
#   '',
#   ''),
#  ('punam',
#   '@Punampanday87',
#   '2023-04-11T06:06:05.000Z',
#   "punam\n@Punampanday87\n·\n16myou won't want to miss it! \n#VMwareExplore",
#   '',
#   '',
#   '',
#   ''),
#  ('sweety sharma',
#   '@sweetysharma108',
#   '2023-04-11T06:06:03.000Z',
#   "sweety sharma\n@sweetysharma108\n·\n16mAt #VMwareExplore, we're seeing firsthand how multi-cloud innovation is altering the business. It's astounding to witness such countless imaginative thoughts and arrangements in a single spot!",
#   '',
#   '',
#   '',
#   '')]

# %%
tweet
# Out:
# ('sweety sharma',
#  '@sweetysharma108',
#  '2023-04-11T06:06:03.000Z',
#  "sweety sharma\n@sweetysharma108\n·\n16mAt #VMwareExplore, we're seeing firsthand how multi-cloud innovation is altering the business. It's astounding to witness such countless imaginative thoughts and arrangements in a single spot!",
#  '',
#  '',
#  '',
#  '')

# %%
tweet[3]
# Out:
# "sweety sharma\n@sweetysharma108\n·\n16mAt #VMwareExplore, we're seeing firsthand how multi-cloud innovation is altering the business. It's astounding to witness such countless imaginative thoughts and arrangements in a single spot!"

# %%
df["Text"]
# Out:
# 0     Ashutosh mourya
# @Anurag_091
# ·
# 2mThat's somethi...
# 1     m.
# @imshivans7
# ·
# 2mஇது ஒரு சிறப்பு மற்றும் மகி...
# 2     Shivam Singh
# @mrshivam_9
# ·
# 2mThat's something ...
# 3     Kapil mishra
# @imkapil_mishra
# ·
# 2mThe one who h...
# 4     vijay
# @vijay__raj6
# ·
# 2mતે આ માટે કંઈક ખાસ અને ...
# 5     Raja
# @iam_raja100
# ·
# 2mಇದು ವಿಶೇಷ ಮತ್ತು ಸಂತೋಷದ ಸ...
# 6     Arun tiwari
# @Aruntiwari509
# ·
# 3mThat's somethin...
# 7     Pavan thakur
# @Pavan_thakur0
# ·
# 3mਇਹ ਇਸ ਲਈ ਕੁਝ ਖ...
# 8     kanhaiya
# @Rishi_xtp
# ·
# 3mइसके लिए यह कुछ खास और...
# 9     Anubhav
# @Anubhav1t
# ·
# 3mThat's something specia...
# 10    imshivaaye
# @anzalisingh7
# ·
# 4mThat's something ...
# 11    Shree Radhe
# @imradhe95
# ·
# 4mஏய் ட்வீப்ஸ் இந்த ஆ...
# 12    Isshu
# @iamishu09
# ·
# 5mહે ટ્વીપ્સ આ વર્ષની સૌથી ...
# 13    Raghav
# @imraghaav09
# ·
# 5mਹੇ ਟਵੀਪਸ ਸਾਲ ਦੇ ਇਸ ਸਭ ...
# 14    Ashutosh mourya
# @Anurag_091
# ·
# 5mਹੇ ਟਵੀਪਸ ਸਾਲ ਦ...
# 15    mr_shivay
# @iam_shivay7
# ·
# 5mਹੇ ਟਵੀਪਸ ਸਾਲ ਦੇ ਇਸ ...
# 16    Mr Rangbaz
# @mr_rangbaz18
# ·
# 6mनमस्ते ट्वीट्स वर...
# 17    𝐌𝐚𝐧_𝐄𝐞𝐬𝐡™
# @Mr_Python17
# ·
# 6mThe biggest multi-c...
# 18    Satish
# @irock_man080
# ·
# 6mHey tweeps don't miss...
# 19    Arman Malik
# @Armanmalik9582
# ·
# 9mThe Biggest #M...
# 20    sonam gupta
# @sonamgupta124
# ·
# 13m#VMwareExplore...
# 21    Khushi verma
# @khushiverma100
# ·
# 14mAt #VMwareEx...
# 22    Sapna
# @Sapna_T01
# ·
# 14mise dekhne ke bad mujhe ...
# 23    Karan Kundra
# @Kundrakaran23
# ·
# 14mEveryone shou...
# 24    Saurabh Mlm Srivastava
# @MlmSaurabh
# ·
# 14mత్వరపడ...
# 25    Radha
# @Radhagupta87
# ·
# 14m#VMwareExplore,
# the l...
# 26    Deepa
# @Deeps_d1
# ·
# 14mSabhi logon Ko iske sath ...
# 27    Avinash
# @Craziavi707160
# ·
# 14mVMware ఎక్స్‌ప్లో...
# 28    Namrata Singh
# @NamrataSingh520
# ·
# 14mWe can't w...
# 29    Virat Kohli
# @imVkohali18
# ·
# 15m#VMwareExplore '...
# 30    Kajal Tiwari
# @Tiwa_Kajal
# ·
# 15mbahut hi behtari...
# 31    Aarohiyadav
# @Aarohiyadav444
# ·
# 15m#VMwareExplor...
# 32    Mukesh Parmar™
# @mukeshparmar146
# ·
# 15mਸਭ ਤੋਂ ਵੱ...
# 33    Preeti Singh
# @PreetiKumari520
# ·
# 15m#VMwareExpl...
# 34    Suman
# @Sig_uttam
# ·
# 15msabhi ko is event ko dek...
# 35    Punam Singh
# @PoojaSingh520
# ·
# 16mMumbai is buzz...
# 36    govind kumar
# @praveshdoor
# ·
# 16mThe Jio World C...
# 37    Rani pandey
# @Ranipanday124
# ·
# 16mThe Jio World ...
# 38    Abhi
# @Abhi86_
# ·
# 16mOne more great event is her...
# 39    Shree Radhe
# @imradhe95
# ·
# 16mಇದು ಮುಂಬೈನಲ್ಲಿ ನಡೆ...
# 40    Parul Patel
# @Parul2fb
# ·
# 16mIf you want to see ...
# 41    Jyoti Singh
# @Jyoti_S12
# ·
# 16mYah interesting ev...
# 42    punam
# @Punampanday87
# ·
# 16myou won't want to mi...
# 43    sweety sharma
# @sweetysharma108
# ·
# 16mAt #VMware...
# Name: Text, dtype: string

# %%
twitter_tweet
# Out:
# <StringArray>
# [                                                                                                                                                      "Ashutosh mourya\n@Anurag_091\n·\n2mThat's something special and happy for this one #VMwareExplore",
#                                                                                                                                                                         'm.\n@imshivans7\n·\n2mஇது ஒரு சிறப்பு மற்றும் மகிழ்ச்சியான விஷயம் #VMwareExplore',
#                                                                                                                                                           "Shivam Singh\n@mrshivam_9\n·\n2mThat's something special and happy for this one #VMwareExplore",
#                                                   'Kapil mishra\n@imkapil_mishra\n·\n2mThe one who has medicine for every pain.... That unique relationship is parents...\n#भ्रष्टाचार_खिलाफ_पायलट\n#VMwareExplore\n#ClimateSmartUP\n#VMwareIndia #TejRan',
#                                                                                                                                                                                   'vijay\n@vijay__raj6\n·\n2mતે આ માટે કંઈક ખાસ અને ખુશ છે #VMwareExplore',
#                                                                                                                                                                               'Raja\n@iam_raja100\n·\n2mಇದು ವಿಶೇಷ ಮತ್ತು ಸಂತೋಷದ ಸಂಗತಿಯಾಗಿದೆ #VMwareExplore',
#                                                                                                                                                         "Arun tiwari\n@Aruntiwari509\n·\n3mThat's something special and happy for this one #VMwareExplore",
#                                                                                                                                                                 'Pavan thakur\n@Pavan_thakur0\n·\n3mਇਹ ਇਸ ਲਈ ਕੁਝ ਖਾਸ ਅਤੇ ਖੁਸ਼ੀ ਵਾਲੀ ਗੱਲ ਹੈ #VMwareExplore',
#                                                                                                                                                                          'kanhaiya\n@Rishi_xtp\n·\n3mइसके लिए यह कुछ खास और खुशी की बात है #VMwareExplore',
#                                                                                                                                                                 "Anubhav\n@Anubhav1t\n·\n3mThat's something special and happy for this one #VMwareExplore",
#                                                                                                                                                           "imshivaaye\n@anzalisingh7\n·\n4mThat's something special and happy for this one #VMwareExplore",
#                                                                      'Shree Radhe\n@imradhe95\n·\n4mஏய் ட்வீப்ஸ் இந்த ஆண்டின் மிகப்பெரிய மல்டி கிளவுட் நிகழ்வின் ஒரு பகுதியாக இருக்க தவறாதீர்கள் VMware Explore இது மும்பையில் நடக்கிறது.. #VMwareExplore',
#                                                                                             'Isshu\n@iamishu09\n·\n5mહે ટ્વીપ્સ આ વર્ષની સૌથી મોટી મલ્ટી-ક્લાઉડ ઇવેન્ટનો ભાગ બનવાનું ચૂકશો નહીં VMware એક્સપ્લોર જે મુંબઈમાં થઈ રહ્યું છે. #VMwareExplore',
#                                                                                           'Raghav\n@imraghaav09\n·\n5mਹੇ ਟਵੀਪਸ ਸਾਲ ਦੇ ਇਸ ਸਭ ਤੋਂ ਵੱਡੇ ਮਲਟੀ-ਕਲਾਊਡ ਈਵੈਂਟ ਦਾ ਹਿੱਸਾ ਬਣਨ ਲਈ ਨਾ ਭੁੱਲੋ VMware ਐਕਸਪਲੋਰ ਜੋ ਕਿ ਮੁੰਬਈ ਵਿੱਚ ਹੋ ਰਿਹਾ ਹੈ. #VMwareExplore',
#                                                                                   'Ashutosh mourya\n@Anurag_091\n·\n5mਹੇ ਟਵੀਪਸ ਸਾਲ ਦੇ ਇਸ ਸਭ ਤੋਂ ਵੱਡੇ ਮਲਟੀ-ਕਲਾਊਡ ਈਵੈਂਟ ਦਾ ਹਿੱਸਾ ਬਣਨ ਲਈ ਨਾ ਭੁੱਲੋ VMware ਐਕਸਪਲੋਰ ਜੋ ਕਿ ਮੁੰਬਈ ਵਿੱਚ ਹੋ ਰਿਹਾ ਹੈ. #VMwareExplore',
#                                                                                        'mr_shivay\n@iam_shivay7\n·\n5mਹੇ ਟਵੀਪਸ ਸਾਲ ਦੇ ਇਸ ਸਭ ਤੋਂ ਵੱਡੇ ਮਲਟੀ-ਕਲਾਊਡ ਈਵੈਂਟ ਦਾ ਹਿੱਸਾ ਬਣਨ ਲਈ ਨਾ ਭੁੱਲੋ VMware ਐਕਸਪਲੋਰ ਜੋ ਕਿ ਮੁੰਬਈ ਵਿੱਚ ਹੋ ਰਿਹਾ ਹੈ. #VMwareExplore',
#                                                                               'Mr Rangbaz\n@mr_rangbaz18\n·\n6mनमस्ते ट्वीट्स वर्ष के इस सबसे बड़े मल्टी-क्लाउड इवेंट का हिस्सा बनने से न चूकें वीएमवेयर एक्सप्लोर जो मुंबई में हो रहा है. #VMwareExplore',
#                                                                                   '𝐌𝐚𝐧_𝐄𝐞𝐬𝐡™\n@Mr_Python17\n·\n6mThe biggest multi-cloud event of the year #VMwareExplore is happening right now in Mumbai! An absolute paradise for all the tech lovers!',
#                                                                             "Satish\n@irock_man080\n·\n6mHey tweeps don't miss to be a part of this biggest multi-cloud event of the year VMware Explore which is happening  ow in Mumbai. #VMwareExplore",
#                                                                                                                                            'Arman Malik\n@Armanmalik9582\n·\n9mThe Biggest #Multicloud event #VMwareExplore is now happening in Mumbai !!',
#                                                                                                                    "sonam gupta\n@sonamgupta124\n·\n13m#VMwareExplore, we're seeing firsthand how multi-cloud technology is revolutionizing the industry.",
#                                                                                                                                                                       "Khushi verma\n@khushiverma100\n·\n14mAt #VMwareExplore, we're seeing firsthand how",
#                                                                                                                          'Sapna\n@Sapna_T01\n·\n14mise dekhne ke bad mujhe bahut hi Khushi Hui main yahan se bahut kuchh sikhane wala hun\n#VMwareExplore',
#                                                                                                                                                                   'Karan Kundra\n@Kundrakaran23\n·\n14mEveryone should take a look at this #VMwareExplore',
#                                                                                                                                    'Saurabh Mlm Srivastava\n@MlmSaurabh\n·\n14mత్వరపడండి అబ్బాయిలు ఈ ఈవెంట్\u200cలో దేనినీ మిస్ చేసుకోకండి #VMwareExplore',
#                                                                                                                                                                'Radha\n@Radhagupta87\n·\n14m#VMwareExplore,\nthe latest trends in multi-cloud technology!',
#                                                                                               'Deepa\n@Deeps_d1\n·\n14mSabhi logon Ko iske sath judna chahie aur ise dekhna chahie Jahan per hamen bahut kuchh sikhane ko milane wala hai\n#VMwareExplore',
#                                                                 'Avinash\n@Craziavi707160\n·\n14mVMware ఎక్స్\u200cప్లోర్ ఈవెంట్ పూర్తి స్వింగ్\u200cలో ఉంది! అన్ని స్ఫూర్తిని పొందడం మరియు ఈవెంట్ ఆఫర్\u200cలను నేర్చుకోవడం ఆనందంగా ఉంది! #VMwareExplore',
#                                                                                                                    "Namrata Singh\n@NamrataSingh520\n·\n14mWe can't wait to learn more about the latest trends in multi-cloud technology\n#VMwareExplore,",
#                                                                               "Virat Kohli\n@imVkohali18\n·\n15m#VMwareExplore 'ਤੇ ਉਤਸ਼ਾਹ ਦੇਖਣਯੋਗ ਹੈ, ਮੁੰਬਈ ਵਿੱਚ ਹੋਣ ਵਾਲੇ ਅੰਤਮ ਮਲਟੀ-ਕਲਾਊਡ ਇਵੈਂਟ!  ਇਹ ਇਵੈਂਟ ਉੱਥੇ ਮੌਜੂਦ ਸਾਰੇ ਤਕਨੀਕੀ ਉਤਸ਼ਾਹੀਆਂ ਲਈ ਲਾਜ਼ਮੀ ਹੈ!",
#                                                                                         'Kajal Tiwari\n@Tiwa_Kajal\n·\n15mbahut hi behtarin program organised Kiya Gaya hai Jahan per hamen acchi chijen dekhne ko milane wali hai yaaron\n#VMwareExplore',
#                                                                                                                     "Aarohiyadav\n@Aarohiyadav444\n·\n15m#VMwareExplore event takes center stage!  We can't wait to learn more about the latest trends in",
#                                                                                  'Mukesh Parmar™\n@mukeshparmar146\n·\n15mਸਭ ਤੋਂ ਵੱਡੇ  ਮਲਟੀਕਲਾਉਡ ਇਵੈਂਟ ਦਾ ਦਰਵਾਜ਼ਾ - #VMwareExplore ਹੁਣ ਖੁੱਲ੍ਹਾ ਹੈ!  ਇਸ ਵਿਸ਼ਾਲਤਾ ਦੀ ਘਟਨਾ ਨੂੰ ਦੇਖ ਕੇ ਕਿੰਨੀ ਖ਼ੁਸ਼ੀ ਹੁੰਦੀ ਹੈ!',
#                                                                                                                                                                           'Preeti Singh\n@PreetiKumari520\n·\n15m#VMwareExplore event takes center stage!',
#                                                                                                                        'Suman\n@Sig_uttam\n·\n15msabhi ko is event ko dekhna chahie ya Hamare knowledge ko enhance karne mein help Karega\n#VMwareExplore',
#                                                                                                                                                                   'Punam Singh\n@PoojaSingh520\n·\n16mMumbai is buzzing with energy as the #VMwareExplore',
#  'govind kumar\n@praveshdoor\n·\n16mThe Jio World Center in Mumbai is humming with energy as the #VMwareExplore occasion becomes the dominant focal point! We can hardly hold on to get familiar with the most recent patterns in multi-cloud innovation!',
#                                                                                                                                           'Rani pandey\n@Ranipanday124\n·\n16mThe Jio World Center in Mumbai is buzzing with energy as the #VMwareExplore',
#                                                                                                                                                                     "Abhi\n@Abhi86_\n·\n16mOne more great event is here let's support this #VMwareExplore",
#                                                                                                                                  'Shree Radhe\n@imradhe95\n·\n16mಇದು ಮುಂಬೈನಲ್ಲಿ ನಡೆಯುತ್ತಿರುವ ಮಹೋನ್ನತ ಘಟನೆಯಾಗಿದೆ ಮತ್ತು ಇದು ಟೆಕ್ ಪ್ರಿಯರಿಗಾಗಿ #VMwareExplore',
#                                                                                                                                          'Parul Patel\n@Parul2fb\n·\n16mIf you want to see something good then you should see this event \n#VMwareExplore',
#                                                                                                         'Jyoti Singh\n@Jyoti_S12\n·\n16mYah interesting event dekhne ke liye main excited hun yahan per behtarin Anubhav dekhne ko milega\n#VMwareExplore',
#                                                                                                                                                                                 "punam\n@Punampanday87\n·\n16myou won't want to miss it! \n#VMwareExplore",
#                  "sweety sharma\n@sweetysharma108\n·\n16mAt #VMwareExplore, we're seeing firsthand how multi-cloud innovation is altering the business. It's astounding to witness such countless imaginative thoughts and arrangements in a single spot!"]
# Length: 44, dtype: string

# %%
import pandas as pd
# Read the CSV file into a DataFrame
MYdata = pd.read_csv('C:/Users/kldat/Downloads/mydata.csv')

# Print the DataFrame
MYdata.head()
# Out:
#                 UserName            Handle                 Timestamp  \
# 0  Tirumalaa Coconut Oil     @TirumalaaOil  2023-04-06T04:59:15.000Z
# 1           Sonika singh    @Imsonikasingh  2023-04-06T04:59:09.000Z
# 2        Mandeep RajBhar  @MandeepRajBhar_  2023-04-06T04:59:09.000Z
# 3       Bhuvanesh Sharma       @bhuvanhere  2023-04-06T04:58:01.000Z
# 4           Nimish Raval      @RavalNimish  2023-04-06T04:57:57.000Z
#
#                                                 Text Emojis  Comments  Likes  \
# 0  Tirumalaa Coconut Oil\n@TirumalaaOil\n·\n17sMa...    NaN       NaN    NaN
# 1  Sonika singh\n@Imsonikasingh\n·\n23sसाधु संत क...      🚩       NaN    NaN
# 2  Mandeep RajBhar\n@MandeepRajBhar_\n·\n23sRam k...    NaN       NaN    NaN
# 3  Bhuvanesh Sharma\n@bhuvanhere\n·\n1mजय बजरंग ब...      🙏       NaN    NaN
# 4  Nimish Raval\n@RavalNimish\n·\n1mअंजनी पुत्र श...    🎈 🚩       NaN    NaN
#
#    Retweets
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
MYdata['Text'] = twitter_tweet
MYdata.head()
# Out:
#                 UserName            Handle                 Timestamp  \
# 0  Tirumalaa Coconut Oil     @TirumalaaOil  2023-04-06T04:59:15.000Z
# 1           Sonika singh    @Imsonikasingh  2023-04-06T04:59:09.000Z
# 2        Mandeep RajBhar  @MandeepRajBhar_  2023-04-06T04:59:09.000Z
# 3       Bhuvanesh Sharma       @bhuvanhere  2023-04-06T04:58:01.000Z
# 4           Nimish Raval      @RavalNimish  2023-04-06T04:57:57.000Z
#
#                                                 Text Emojis  Comments  Likes  \
# 0  Tirumalaa Coconut Oil
# @TirumalaaOil
# ·
# 17sMay H...    NaN       NaN    NaN
# 1  Sonika singh
# @Imsonikasingh
# ·
# 23sसाधु संत के त...      🚩       NaN    NaN
# 2  Mandeep RajBhar
# @MandeepRajBhar_
# ·
# 23sRam ke B...    NaN       NaN    NaN
# 3  Bhuvanesh Sharma
# @bhuvanhere
# ·
# 1mजय बजरंग बली ...      🙏       NaN    NaN
# 4  Nimish Raval
# @RavalNimish
# ·
# 1mअंजनी पुत्र श्री...    🎈 🚩       NaN    NaN
#
#    Retweets
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
MYdata['Text'][0]
# Out:
# 'Tirumalaa Coconut Oil\n@TirumalaaOil\n·\n17sMay Hanuman ji is always there to bless you with happiness, good fortune, and health. Warm wishes on Hanuman Janmotsav. \n.\n.\n#HanumanJanmotsav #HanumanJayanti #हनुमान_जन्मोत्सव #हनुमान_जयंती'

# %%
MYdata.to_csv('UpdatedData.csv', index=False,encoding='utf-8')
